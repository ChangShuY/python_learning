# %%
# %run train21.py
# Out:
# (0,0):avg_loss_value[0]= 492.774475
# name: "mean_10.tmp_0"
# type {
#   type: LOD_TENSOR
#   lod_tensor {
#     tensor {
#       data_type: FP32
#       dims: 1
#     }
#   }
# }
# persistable: false
#
# [(array([-0.03918128,  0.18636364, -0.22752121, -0.06916996, -0.26068942,
#         0.02076367, -0.62590012,  0.29467007, -0.15432205, -0.20655945,
#        -0.19739719,  0.04547876, -0.20593442]), array([23.7])), (array([-0.04013171,  0.68636364, -0.33822502, -0.06916996, -0.29155362,
#        -0.11910987, -0.48068899,  0.61750651, -0.24127857, -0.14167396,
#         0.37707089,  0.06587818, -0.12701609]), array([18.2])), (array([-0.03988837,  0.58636364, -0.32612825, -0.06916996, -0.31830259,
#         0.01156651, -0.49922658,  0.36671765, -0.19780031, -0.09587243,
#        -0.38888655,  0.02916428, -0.21200506]), array([22.5])), (array([-0.04022792,  0.71136364, -0.3338262 , -0.06916996, -0.28743839,
#        -0.02349768, -0.31076108,  0.22505955, -0.32823509, -0.1149564 ,
# ...

# %%
print("%f; data_train= %f; avg_loss_value= %f; avg_loss_value[0]= %f" %
              (1.1,2.2,3.3,4.4))
# Out:
# 1.100000; data_train= 2.200000; avg_loss_value= 3.300000; avg_loss_value[0]= 4.400000
